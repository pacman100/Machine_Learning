# %%
import numpy as np
#import sklearn as sk
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import csv
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import confusion_matrix
# Out:
# /home/sourab/anaconda3/envs/tf/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
print(tf.__version__)
#print(sk.__version__)
print(np.__version__)
# Out:
# 1.4.0
# 1.13.3

# %%
x_train = []
y_train = []
x_valid = []
y_valid = []
x_test = []
y_test = []

with open('./group8/class1_train.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_train.append([float(a), float(b)])
        y_train.append(1)

with open('./group8/class2_train.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_train.append([float(a), float(b)])
        y_train.append(2)

with open('./group8/class3_train.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_train.append([float(a), float(b)])
        y_train.append(3)
        


with open('./group8/class1_val.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_valid.append([float(a), float(b)])
        y_valid.append(1)

with open('./group8/class2_val.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_valid.append([float(a), float(b)])
        y_valid.append(2)

with open('./group8/class3_val.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_valid.append([float(a), float(b)])
        y_valid.append(3)
        
        
        
with open('./group8/class1_test.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_test.append([float(a), float(b)])
        y_test.append(1)

with open('./group8/class2_test.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_test.append([float(a), float(b)])
        y_test.append(2)

with open('./group8/class3_test.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_test.append([float(a), float(b)])
        y_test.append(3)
        

x_train = np.array(x_train)
y_train = np.array(y_train)
x_valid = np.array(x_valid)
y_valid = np.array(y_valid)
x_test = np.array(x_test)
y_test = np.array(y_test)

plt.plot(x_train[:,0], x_train[:,1], 'ro')
plt.xlabel('X1 Value')
plt.ylabel('X2 Value')
plt.title('Linearly Separable Training Dataset (Group-8)')
plt.show()

# %%
clf = SVC()
clf.fit(x_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred_train = clf.predict(x_train)
acc = clf.score(x_train, y_train)
print("The accuracy of the SVM model on the training data:", acc*100,"%")

plot_decision_regions(x_train, y_train, clf=clf, legend=3)
plt.show()

#confusion Matrix
confusion_matrix(y_train, y_pred_train,labels=[1, 2, 3])
# Out:
# The accuracy of the SVM model on the training data: 99.6 %
# array([[249,   1,   0],
#        [  0, 250,   0],
#        [  1,   1, 248]])

# %%
y_pred_valid = clf.predict(x_valid)
acc = clf.score(x_valid, y_valid)
print("The accuracy of the SVM model on the validation data:", acc*100,"%")

plot_decision_regions(x_valid, y_valid, clf=clf, legend=3)
plt.show()

#confusion Matrix
confusion_matrix(y_valid, y_pred_valid,labels=[1, 2, 3])
# Out:
# The accuracy of the SVM model on the validation data: 99.1111111111 %
# array([[147,   1,   2],
#        [  0, 149,   1],
#        [  0,   0, 150]])

# %%
y_pred_test = clf.predict(x_test)
acc = clf.score(x_test, y_test)
print("The accuracy of the SVM model on the Test data:", acc*100,"%")

plot_decision_regions(x_test, y_test, clf=clf, legend=3)
plt.show()

#confusion Matrix
confusion_matrix(y_test, y_pred_test,labels=[1, 2, 3])
# Out:
# The accuracy of the SVM model on the Test data: 99.0 %
# array([[100,   0,   0],
#        [  0, 100,   0],
#        [  2,   1,  97]])
