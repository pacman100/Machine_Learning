# %%
import numpy as np
#import sklearn as sk
from sklearn.svm import LinearSVC
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import csv
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import confusion_matrix

# %%
print(tf.__version__)
#print(sk.__version__)
print(np.__version__)
# Out:
# 1.4.0
# 1.13.3

# %%
x_train = []
y_train = []
x_valid = []
y_valid = []
x_test = []
y_test = []

with open('./group8/class1_train.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_train.append([float(a), float(b)])
        y_train.append(1)

with open('./group8/class2_train.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_train.append([float(a), float(b)])
        y_train.append(2)

with open('./group8/class3_train.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_train.append([float(a), float(b)])
        y_train.append(3)
        


with open('./group8/class1_val.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_valid.append([float(a), float(b)])
        y_valid.append(1)

with open('./group8/class2_val.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_valid.append([float(a), float(b)])
        y_valid.append(2)

with open('./group8/class3_val.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_valid.append([float(a), float(b)])
        y_valid.append(3)
        
        
        
with open('./group8/class1_test.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_test.append([float(a), float(b)])
        y_test.append(1)

with open('./group8/class2_test.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_test.append([float(a), float(b)])
        y_test.append(2)

with open('./group8/class3_test.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_test.append([float(a), float(b)])
        y_test.append(3)
        

x_train = np.array(x_train)
y_train = np.array(y_train)
x_valid = np.array(x_valid)
y_valid = np.array(y_valid)
x_test = np.array(x_test)
y_test = np.array(y_test)

plt.plot(x_train[:,0], x_train[:,1], 'ro')
plt.xlabel('X1 Value')
plt.ylabel('X2 Value')
plt.title('Linearly Separable Training Dataset (Group-8)')
plt.show()

# %%
clf = LinearSVC()
clf.fit(x_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
y_pred_train = clf.predict(x_train)
acc = clf.score(x_train, y_train)
print("The accuracy of the Linear SVM model on the training data:", acc*100,"%")

plot_decision_regions(x_train, y_train, clf=clf, legend=3)
plt.show()

#confusion Matrix
confusion_matrix(y_train, y_pred_train,labels=[1, 2, 3])
# Out:
# The accuracy of the Linear SVM model on the training data: 100.0 %
# array([[250,   0,   0],
#        [  0, 250,   0],
#        [  0,   0, 250]])

# %%
y_pred_valid = clf.predict(x_valid)
acc = clf.score(x_valid, y_valid)
print("The accuracy of the Linear SVM model on the validation data:", acc*100,"%")


plot_decision_regions(x_valid, y_valid, clf=clf, legend=3)
plt.show()

#confusion Matrix
confusion_matrix(y_valid, y_pred_valid,labels=[1, 2, 3])
# Out:
# The accuracy of the Linear SVM model on the validation data: 100.0 %
# array([[150,   0,   0],
#        [  0, 150,   0],
#        [  0,   0, 150]])

# %%
y_pred_test = clf.predict(x_test)
acc = clf.score(x_test, y_test)
print("The accuracy of the Linear SVM model on the Test data:", acc*100,"%")

plot_decision_regions(x_test, y_test, clf=clf, legend=3)
plt.show()

#confusion Matrix
confusion_matrix(y_test, y_pred_test,labels=[1, 2, 3])
# Out:
# The accuracy of the Linear SVM model on the Test data: 100.0 %
# array([[100,   0,   0],
#        [  0, 100,   0],
#        [  0,   0, 100]])
