# %%
#importing Keras  and other libraries

import time
import numpy as np
from matplotlib import pyplot as plt
from keras.utils import np_utils
import keras.callbacks as cb
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import confusion_matrix

# %%
class LossHistory(cb.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        batch_loss = logs.get('loss')
        self.losses.append(batch_loss)

# %%
#Data Loading and Preprocessing 

x_train = []
y_train = []
x_valid = []
y_valid = []
x_test = []
y_test = []

with open('./group8/class1_train.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_train.append([float(a), float(b)])
        y_train.append(0)

with open('./group8/class2_train.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_train.append([float(a), float(b)])
        y_train.append(1)

with open('./group8/class3_train.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_train.append([float(a), float(b)])
        y_train.append(2)
        


with open('./group8/class1_val.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_valid.append([float(a), float(b)])
        y_valid.append(0)

with open('./group8/class2_val.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_valid.append([float(a), float(b)])
        y_valid.append(1)

with open('./group8/class3_val.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_valid.append([float(a), float(b)])
        y_valid.append(2)
        
        
        
with open('./group8/class1_test.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_test.append([float(a), float(b)])
        y_test.append(0)

with open('./group8/class2_test.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_test.append([float(a), float(b)])
        y_test.append(1)

with open('./group8/class3_test.txt', 'r') as file:
    for row in file:
        a,b = row.split()
        x_test.append([float(a), float(b)])
        y_test.append(2)
        

x_train = np.array(x_train)
y_train = np.array(y_train)
y_train_vec = np_utils.to_categorical(y_train, 3)
x_valid = np.array(x_valid)
y_valid = np.array(y_valid)
y_valid_vec = np_utils.to_categorical(y_valid, 3)
x_test = np.array(x_test)
y_test = np.array(y_test)
y_test_vec = np_utils.to_categorical(y_test, 3)

plt.plot(x_train[:,0], x_train[:,1], 'ro')
plt.xlabel('X1 Value')
plt.ylabel('X2 Value')
plt.title('Linearly Separable Training Dataset (Group-8)')
plt.show()

# %%
def init_model():
    model = Sequential()
    #model.add(Dense(128, activation='relu', input_dim=2))
    #model.add(Dropout(0.5))
    #model.add(Dense(128, activation='relu'))
    #model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax', input_dim=2))
    
    sgd = SGD()
    
    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

    return model

# %%
model = init_model()
history = LossHistory()
model.fit(x_train, y_train_vec,epochs=300,batch_size=128,callbacks=[history],validation_data=(x_valid, y_valid_vec), verbose=2)
score = model.evaluate(x_test, y_test_vec, batch_size=128)
print("Network's test score [loss, accuracy]: {0}".format(score))
# Out:
# Train on 750 samples, validate on 450 samples
# Epoch 1/300
#  - 1s - loss: 9.0050 - acc: 0.1320 - val_loss: 7.5913 - val_acc: 0.2000
# Epoch 2/300
#  - 0s - loss: 6.8696 - acc: 0.2853 - val_loss: 6.2193 - val_acc: 0.4133
# Epoch 3/300
#  - 0s - loss: 6.1379 - acc: 0.4467 - val_loss: 6.0067 - val_acc: 0.4978
# Epoch 4/300
#  - 0s - loss: 6.0353 - acc: 0.4827 - val_loss: 5.9643 - val_acc: 0.5067
# Epoch 5/300
#  - 0s - loss: 6.0102 - acc: 0.4933 - val_loss: 5.9464 - val_acc: 0.5111
# Epoch 6/300
#  - 0s - loss: 5.9972 - acc: 0.4947 - val_loss: 5.9346 - val_acc: 0.5133
# Epoch 7/300
#  - 0s - loss: 5.9873 - acc: 0.4947 - val_loss: 5.9251 - val_acc: 0.5156
# Epoch 8/300
#  - 0s - loss: 5.9788 - acc: 0.4960 - val_loss: 5.9167 - val_acc: 0.5200
# Epoch 9/300
#  - 0s - loss: 5.9706 - acc: 0.4960 - val_loss: 5.9091 - val_acc: 0.5200
# Epoch 10/300
#  - 0s - loss: 5.9627 - acc: 0.4987 - val_loss: 5.9016 - val_acc: 0.5222
# Epoch 11/300
#  - 0s - loss: 5.9549 - acc: 0.4987 - val_loss: 5.8944 - val_acc: 0.5244
# Epoch 12/300
#  - 0s - loss: 5.9473 - acc: 0.5000 - val_loss: 5.8874 - val_acc: 0.5244
# Epoch 13/300
#  - 0s - loss: 5.9396 - acc: 0.5013 - val_loss: 5.8806 - val_acc: 0.5289
# Epoch 14/300
#  - 0s - loss: 5.9322 - acc: 0.5027 - val_loss: 5.8739 - val_acc: 0.5289
# Epoch 15/300
#  - 0s - loss: 5.9248 - acc: 0.5053 - val_loss: 5.8673 - val_acc: 0.5311
# Epoch 16/300
#  - 0s - loss: 5.9175 - acc: 0.5067 - val_loss: 5.8608 - val_acc: 0.5311
# Epoch 17/300
#  - 0s - loss: 5.9102 - acc: 0.5080 - val_loss: 5.8543 - val_acc: 0.5311
# Epoch 18/300
#  - 0s - loss: 5.9029 - acc: 0.5093 - val_loss: 5.8478 - val_acc: 0.5311
# Epoch 19/300
#  - 0s - loss: 5.8958 - acc: 0.5093 - val_loss: 5.8414 - val_acc: 0.5311
# Epoch 20/300
#  - 0s - loss: 5.8887 - acc: 0.5107 - val_loss: 5.8352 - val_acc: 0.5311
# Epoch 21/300
#  - 0s - loss: 5.8817 - acc: 0.5120 - val_loss: 5.8290 - val_acc: 0.5311
# Epoch 22/300
#  - 0s - loss: 5.8747 - acc: 0.5120 - val_loss: 5.8229 - val_acc: 0.5311
# Epoch 23/300
#  - 0s - loss: 5.8680 - acc: 0.5133 - val_loss: 5.8168 - val_acc: 0.5311
# Epoch 24/300
#  - 0s - loss: 5.8611 - acc: 0.5133 - val_loss: 5.8108 - val_acc: 0.5311
# Epoch 25/300
#  - 0s - loss: 5.8544 - acc: 0.5133 - val_loss: 5.8049 - val_acc: 0.5311
# Epoch 26/300
#  - 0s - loss: 5.8477 - acc: 0.5147 - val_loss: 5.7991 - val_acc: 0.5311
# Epoch 27/300
#  - 0s - loss: 0.0983 - acc: 1.0000 - val_loss: 0.0939 - val_acc: 0.9978
# Epoch 177/300
#  - 0s - loss: 0.0978 - acc: 1.0000 - val_loss: 0.0935 - val_acc: 0.9978
# Epoch 178/300
#  - 0s - loss: 0.0973 - acc: 1.0000 - val_loss: 0.0930 - val_acc: 0.9978
# Epoch 179/300
#  - 0s - loss: 0.0968 - acc: 1.0000 - val_loss: 0.0926 - val_acc: 0.9978
# Epoch 180/300
#  - 0s - loss: 0.0964 - acc: 1.0000 - val_loss: 0.0921 - val_acc: 0.9978
# Epoch 181/300
#  - 0s - loss: 0.0959 - acc: 1.0000 - val_loss: 0.0917 - val_acc: 0.9978
# Epoch 182/300
#  - 0s - loss: 0.0954 - acc: 1.0000 - val_loss: 0.0912 - val_acc: 0.9978
# Epoch 183/300
#  - 0s - loss: 0.0950 - acc: 1.0000 - val_loss: 0.0908 - val_acc: 0.9978
# Epoch 184/300
#  - 0s - loss: 0.0945 - acc: 1.0000 - val_loss: 0.0903 - val_acc: 0.9978
# Epoch 185/300
#  - 0s - loss: 0.0940 - acc: 1.0000 - val_loss: 0.0899 - val_acc: 0.9978
# Epoch 186/300
#  - 0s - loss: 0.0936 - acc: 1.0000 - val_loss: 0.0895 - val_acc: 0.9978
# Epoch 187/300
#  - 0s - loss: 0.0932 - acc: 1.0000 - val_loss: 0.0891 - val_acc: 0.9978
# Epoch 188/300
#  - 0s - loss: 0.0927 - acc: 1.0000 - val_loss: 0.0886 - val_acc: 0.9978
# Epoch 189/300
#  - 0s - loss: 0.0923 - acc: 1.0000 - val_loss: 0.0882 - val_acc: 0.9978
# Epoch 190/300
#  - 0s - loss: 0.0919 - acc: 1.0000 - val_loss: 0.0878 - val_acc: 0.9978
# Epoch 191/300
#  - 0s - loss: 0.0914 - acc: 1.0000 - val_loss: 0.0874 - val_acc: 0.9978
# Epoch 192/300
#  - 0s - loss: 0.0910 - acc: 1.0000 - val_loss: 0.0870 - val_acc: 0.9978
# Epoch 193/300
#  - 0s - loss: 0.0906 - acc: 1.0000 - val_loss: 0.0866 - val_acc: 0.9978
# Epoch 194/300
#  - 0s - loss: 0.0902 - acc: 1.0000 - val_loss: 0.0862 - val_acc: 0.9978
# Epoch 195/300
#  - 0s - loss: 0.0898 - acc: 1.0000 - val_loss: 0.0858 - val_acc: 0.9978
# Epoch 196/300
#  - 0s - loss: 0.0894 - acc: 1.0000 - val_loss: 0.0854 - val_acc: 0.9978
# Epoch 197/300
#  - 0s - loss: 0.0889 - acc: 1.0000 - val_loss: 0.0850 - val_acc: 0.9978
# Epoch 198/300
#  - 0s - loss: 0.0885 - acc: 1.0000 - val_loss: 0.0847 - val_acc: 0.9978
# Epoch 199/300
#  - 0s - loss: 0.0881 - acc: 1.0000 - val_loss: 0.0843 - val_acc: 1.0000
# Epoch 200/300
#  - 0s - loss: 0.0878 - acc: 1.0000 - val_loss: 0.0839 - val_acc: 1.0000
# Epoch 201/300
#  - 0s - loss: 0.0874 - acc: 1.0000 - val_loss: 0.0835 - val_acc: 1.0000
# Epoch 202/300
#  - 0s - loss: 0.0870 - acc: 1.0000 - val_loss: 0.0831 - val_acc: 1.0000
# Epoch 203/300
#  - 0s - loss: 0.0866 - acc: 1.0000 - val_loss: 0.0828 - val_acc: 1.0000
# Epoch 204/300
#  - 0s - loss: 0.0862 - acc: 1.0000 - val_loss: 0.0824 - val_acc: 1.0000
# Epoch 205/300
#  - 0s - loss: 0.0858 - acc: 1.0000 - val_loss: 0.0821 - val_acc: 1.0000
# Epoch 206/300
#  - 0s - loss: 0.0855 - acc: 1.0000 - val_loss: 0.0817 - val_acc: 1.0000
# Epoch 207/300
#  - 0s - loss: 0.0851 - acc: 1.0000 - val_loss: 0.0813 - val_acc: 1.0000
# Epoch 208/300
#  - 0s - loss: 0.0847 - acc: 1.0000 - val_loss: 0.0810 - val_acc: 1.0000
# Epoch 209/300
#  - 0s - loss: 0.0844 - acc: 1.0000 - val_loss: 0.0807 - val_acc: 1.0000
# Epoch 210/300
#  - 0s - loss: 0.0840 - acc: 1.0000 - val_loss: 0.0803 - val_acc: 1.0000
# Epoch 211/300
#  - 0s - loss: 0.0836 - acc: 1.0000 - val_loss: 0.0800 - val_acc: 1.0000
# Epoch 212/300
#  - 0s - loss: 0.0833 - acc: 1.0000 - val_loss: 0.0796 - val_acc: 1.0000
# Epoch 213/300
#  - 0s - loss: 0.0829 - acc: 1.0000 - val_loss: 0.0793 - val_acc: 1.0000
# Epoch 214/300
#  - 0s - loss: 0.0826 - acc: 1.0000 - val_loss: 0.0789 - val_acc: 1.0000
# Epoch 215/300
#  - 0s - loss: 0.0822 - acc: 1.0000 - val_loss: 0.0786 - val_acc: 1.0000
# Epoch 216/300
#  - 0s - loss: 0.0819 - acc: 1.0000 - val_loss: 0.0783 - val_acc: 1.0000
# Epoch 217/300
#  - 0s - loss: 0.0815 - acc: 1.0000 - val_loss: 0.0780 - val_acc: 1.0000
# Epoch 218/300
#  - 0s - loss: 0.0812 - acc: 1.0000 - val_loss: 0.0776 - val_acc: 1.0000
# Epoch 219/300
#  - 0s - loss: 0.0808 - acc: 1.0000 - val_loss: 0.0773 - val_acc: 1.0000
# Epoch 220/300
#  - 0s - loss: 0.0805 - acc: 1.0000 - val_loss: 0.0770 - val_acc: 1.0000
# Epoch 221/300
#  - 0s - loss: 0.0802 - acc: 1.0000 - val_loss: 0.0767 - val_acc: 1.0000
# Epoch 222/300
#  - 0s - loss: 0.0798 - acc: 1.0000 - val_loss: 0.0764 - val_acc: 1.0000
# Epoch 223/300
#  - 0s - loss: 0.0795 - acc: 1.0000 - val_loss: 0.0760 - val_acc: 1.0000
# Epoch 224/300
#  - 0s - loss: 0.0792 - acc: 1.0000 - val_loss: 0.0757 - val_acc: 1.0000
# Epoch 225/300
#  - 0s - loss: 0.0789 - acc: 1.0000 - val_loss: 0.0754 - val_acc: 1.0000
# Epoch 226/300
#  - 0s - loss: 0.0786 - acc: 1.0000 - val_loss: 0.0751 - val_acc: 1.0000
# Epoch 227/300
#  - 0s - loss: 0.0782 - acc: 1.0000 - val_loss: 0.0748 - val_acc: 1.0000
# Epoch 228/300
#  - 0s - loss: 0.0779 - acc: 1.0000 - val_loss: 0.0745 - val_acc: 1.0000
# Epoch 229/300
#  - 0s - loss: 0.0776 - acc: 1.0000 - val_loss: 0.0742 - val_acc: 1.0000
# Epoch 230/300
#  - 0s - loss: 0.0773 - acc: 1.0000 - val_loss: 0.0739 - val_acc: 1.0000
# Epoch 231/300
#  - 0s - loss: 0.0770 - acc: 1.0000 - val_loss: 0.0736 - val_acc: 1.0000
# Epoch 232/300
#  - 0s - loss: 0.0767 - acc: 1.0000 - val_loss: 0.0733 - val_acc: 1.0000
# Epoch 233/300
#  - 0s - loss: 0.0764 - acc: 1.0000 - val_loss: 0.0730 - val_acc: 1.0000
# Epoch 234/300
#  - 0s - loss: 0.0761 - acc: 1.0000 - val_loss: 0.0728 - val_acc: 1.0000
# Epoch 235/300
#  - 0s - loss: 0.0758 - acc: 1.0000 - val_loss: 0.0725 - val_acc: 1.0000
# Epoch 236/300
#  - 0s - loss: 0.0755 - acc: 1.0000 - val_loss: 0.0722 - val_acc: 1.0000
# Epoch 237/300
#  - 0s - loss: 0.0752 - acc: 1.0000 - val_loss: 0.0719 - val_acc: 1.0000
# Epoch 238/300
#  - 0s - loss: 0.0749 - acc: 1.0000 - val_loss: 0.0716 - val_acc: 1.0000
# Epoch 239/300
#  - 0s - loss: 0.0746 - acc: 1.0000 - val_loss: 0.0714 - val_acc: 1.0000
# Epoch 240/300
#  - 0s - loss: 0.0743 - acc: 1.0000 - val_loss: 0.0711 - val_acc: 1.0000
# Epoch 241/300
#  - 0s - loss: 0.0741 - acc: 1.0000 - val_loss: 0.0708 - val_acc: 1.0000
# Epoch 242/300
#  - 0s - loss: 0.0738 - acc: 1.0000 - val_loss: 0.0705 - val_acc: 1.0000
# Epoch 243/300
#  - 0s - loss: 0.0735 - acc: 1.0000 - val_loss: 0.0703 - val_acc: 1.0000
# Epoch 244/300
#  - 0s - loss: 0.0732 - acc: 1.0000 - val_loss: 0.0700 - val_acc: 1.0000
# Epoch 245/300
#  - 0s - loss: 0.0729 - acc: 1.0000 - val_loss: 0.0697 - val_acc: 1.0000
# Epoch 246/300
#  - 0s - loss: 0.0727 - acc: 1.0000 - val_loss: 0.0695 - val_acc: 1.0000
# Epoch 247/300
#  - 0s - loss: 0.0724 - acc: 1.0000 - val_loss: 0.0692 - val_acc: 1.0000
# Epoch 248/300
#  - 0s - loss: 0.0721 - acc: 1.0000 - val_loss: 0.0690 - val_acc: 1.0000
# Epoch 249/300
#  - 0s - loss: 0.0719 - acc: 1.0000 - val_loss: 0.0687 - val_acc: 1.0000
# Epoch 250/300
#  - 0s - loss: 0.0716 - acc: 1.0000 - val_loss: 0.0685 - val_acc: 1.0000
# Epoch 251/300
#  - 0s - loss: 0.0713 - acc: 1.0000 - val_loss: 0.0682 - val_acc: 1.0000
# Epoch 252/300
#  - 0s - loss: 0.0711 - acc: 1.0000 - val_loss: 0.0679 - val_acc: 1.0000
# Epoch 253/300
#  - 0s - loss: 0.0708 - acc: 1.0000 - val_loss: 0.0677 - val_acc: 1.0000
# Epoch 254/300
#  - 0s - loss: 0.0705 - acc: 1.0000 - val_loss: 0.0674 - val_acc: 1.0000
# Epoch 255/300
#  - 0s - loss: 0.0703 - acc: 1.0000 - val_loss: 0.0672 - val_acc: 1.0000
# Epoch 256/300
#  - 0s - loss: 0.0700 - acc: 1.0000 - val_loss: 0.0670 - val_acc: 1.0000
# Epoch 257/300
#  - 0s - loss: 0.0698 - acc: 1.0000 - val_loss: 0.0667 - val_acc: 1.0000
# Epoch 258/300
#  - 0s - loss: 0.0695 - acc: 1.0000 - val_loss: 0.0665 - val_acc: 1.0000
# Epoch 259/300
#  - 0s - loss: 0.0693 - acc: 1.0000 - val_loss: 0.0662 - val_acc: 1.0000
# Epoch 260/300
#  - 0s - loss: 0.0690 - acc: 1.0000 - val_loss: 0.0660 - val_acc: 1.0000
# Epoch 261/300
#  - 0s - loss: 0.0688 - acc: 1.0000 - val_loss: 0.0658 - val_acc: 1.0000
# Epoch 262/300
#  - 0s - loss: 0.0685 - acc: 1.0000 - val_loss: 0.0655 - val_acc: 1.0000
# Epoch 263/300
#  - 0s - loss: 0.0683 - acc: 1.0000 - val_loss: 0.0653 - val_acc: 1.0000
# Epoch 264/300
#  - 0s - loss: 0.0680 - acc: 1.0000 - val_loss: 0.0651 - val_acc: 1.0000
# Epoch 265/300
#  - 0s - loss: 0.0678 - acc: 1.0000 - val_loss: 0.0648 - val_acc: 1.0000
# Epoch 266/300
#  - 0s - loss: 0.0676 - acc: 1.0000 - val_loss: 0.0646 - val_acc: 1.0000
# Epoch 267/300
#  - 0s - loss: 0.0673 - acc: 1.0000 - val_loss: 0.0644 - val_acc: 1.0000
# Epoch 268/300
#  - 0s - loss: 0.0671 - acc: 1.0000 - val_loss: 0.0642 - val_acc: 1.0000
# Epoch 269/300
#  - 0s - loss: 0.0669 - acc: 1.0000 - val_loss: 0.0639 - val_acc: 1.0000
# Epoch 270/300
#  - 0s - loss: 0.0666 - acc: 1.0000 - val_loss: 0.0637 - val_acc: 1.0000
# Epoch 271/300
#  - 0s - loss: 0.0664 - acc: 1.0000 - val_loss: 0.0635 - val_acc: 1.0000
# Epoch 272/300
#  - 0s - loss: 0.0662 - acc: 1.0000 - val_loss: 0.0633 - val_acc: 1.0000
# Epoch 273/300
#  - 0s - loss: 0.0659 - acc: 1.0000 - val_loss: 0.0631 - val_acc: 1.0000
# Epoch 274/300
#  - 0s - loss: 0.0657 - acc: 1.0000 - val_loss: 0.0628 - val_acc: 1.0000
# Epoch 275/300
#  - 0s - loss: 0.0655 - acc: 1.0000 - val_loss: 0.0626 - val_acc: 1.0000
# Epoch 276/300
#  - 0s - loss: 0.0653 - acc: 1.0000 - val_loss: 0.0624 - val_acc: 1.0000
# Epoch 277/300
#  - 0s - loss: 0.0651 - acc: 1.0000 - val_loss: 0.0622 - val_acc: 1.0000
# Epoch 278/300
#  - 0s - loss: 0.0648 - acc: 1.0000 - val_loss: 0.0620 - val_acc: 1.0000
# Epoch 279/300
#  - 0s - loss: 0.0646 - acc: 1.0000 - val_loss: 0.0618 - val_acc: 1.0000
# Epoch 280/300
#  - 0s - loss: 0.0644 - acc: 1.0000 - val_loss: 0.0616 - val_acc: 1.0000
# Epoch 281/300
#  - 0s - loss: 0.0642 - acc: 1.0000 - val_loss: 0.0614 - val_acc: 1.0000
# Epoch 282/300
#  - 0s - loss: 0.0640 - acc: 1.0000 - val_loss: 0.0612 - val_acc: 1.0000
# Epoch 283/300
#  - 0s - loss: 0.0638 - acc: 1.0000 - val_loss: 0.0610 - val_acc: 1.0000
# Epoch 284/300
#  - 0s - loss: 0.0635 - acc: 1.0000 - val_loss: 0.0608 - val_acc: 1.0000
# Epoch 285/300
#  - 0s - loss: 0.0633 - acc: 1.0000 - val_loss: 0.0606 - val_acc: 1.0000
# Epoch 286/300
#  - 0s - loss: 0.0631 - acc: 1.0000 - val_loss: 0.0604 - val_acc: 1.0000
# Epoch 287/300
#  - 0s - loss: 0.0629 - acc: 1.0000 - val_loss: 0.0602 - val_acc: 1.0000
# Epoch 288/300
#  - 0s - loss: 0.0627 - acc: 1.0000 - val_loss: 0.0600 - val_acc: 1.0000
# Epoch 289/300
#  - 0s - loss: 0.0625 - acc: 1.0000 - val_loss: 0.0598 - val_acc: 1.0000
# Epoch 290/300
#  - 0s - loss: 0.0623 - acc: 1.0000 - val_loss: 0.0596 - val_acc: 1.0000
# Epoch 291/300
#  - 0s - loss: 0.0621 - acc: 1.0000 - val_loss: 0.0594 - val_acc: 1.0000
# Epoch 292/300
#  - 0s - loss: 0.0619 - acc: 1.0000 - val_loss: 0.0592 - val_acc: 1.0000
# Epoch 293/300
#  - 0s - loss: 0.0617 - acc: 1.0000 - val_loss: 0.0590 - val_acc: 1.0000
# Epoch 294/300
#  - 0s - loss: 0.0615 - acc: 1.0000 - val_loss: 0.0588 - val_acc: 1.0000
# Epoch 295/300
#  - 0s - loss: 0.0613 - acc: 1.0000 - val_loss: 0.0586 - val_acc: 1.0000
# Epoch 296/300
#  - 0s - loss: 0.0611 - acc: 1.0000 - val_loss: 0.0584 - val_acc: 1.0000
# Epoch 297/300
#  - 0s - loss: 0.0609 - acc: 1.0000 - val_loss: 0.0583 - val_acc: 1.0000
# Epoch 298/300
#  - 0s - loss: 0.0607 - acc: 1.0000 - val_loss: 0.0581 - val_acc: 1.0000
# Epoch 299/300
#  - 0s - loss: 0.0605 - acc: 1.0000 - val_loss: 0.0579 - val_acc: 1.0000
# Epoch 300/300
#  - 0s - loss: 0.0604 - acc: 1.0000 - val_loss: 0.0577 - val_acc: 1.0000
# 300/300 [==============================] - 0s 25us/step
# Network's test score [loss, accuracy]: [0.065374327289561426, 1.0]

# %%
y_pred_train = model.predict(x_train, batch_size=128)
y_pred_train = np.argmax(y_pred_train, axis=1)
score = model.evaluate(x_train, y_train_vec, batch_size=128)
print("The accuracy of the MLFFNN model on the training data:", score[1]*100,"%")

x_min, x_max = x_train[:, 0].min() - 1, x_train[:, 0].max() + 1
y_min, y_max = x_train[:, 1].min() - 1, x_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05),
                     np.arange(y_min, y_max, 0.05))

# here "model" is your model's prediction (classification) function
Z = np.argmax(model.predict(np.c_[xx.ravel(), yy.ravel()]), axis=1)

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.axis('off')

# Plot also the training points
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, cmap=plt.cm.jet)
plt.show()

#confusion Matrix
confusion_matrix(y_train, y_pred_train,labels=[0, 1, 2])
# Out:
# 750/750 [==============================] - 0s 14us/step
# The accuracy of the MLFFNN model on the training data: 100.0 %
# array([[250,   0,   0],
#        [  0, 250,   0],
#        [  0,   0, 250]])

# %%
y_pred_valid = model.predict(x_valid, batch_size=128)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
score = model.evaluate(x_valid, y_valid_vec, batch_size=128)
print("The accuracy of the MLFFNN model on the validation data:", score[1]*100,"%")

x_min, x_max = x_train[:, 0].min() - 1, x_train[:, 0].max() + 1
y_min, y_max = x_train[:, 1].min() - 1, x_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05),
                     np.arange(y_min, y_max, 0.05))

# here "model" is your model's prediction (classification) function
Z = np.argmax(model.predict(np.c_[xx.ravel(), yy.ravel()]), axis=1)

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.axis('off')

# Plot also the training points
plt.scatter(x_valid[:, 0], x_valid[:, 1], c=y_valid, cmap=plt.cm.jet)
plt.show()

#confusion Matrix
confusion_matrix(y_valid, y_pred_valid,labels=[0, 1, 2])
# Out:
# 450/450 [==============================] - 0s 17us/step
# The accuracy of the MLFFNN model on the validation data: 100.0 %
# array([[150,   0,   0],
#        [  0, 150,   0],
#        [  0,   0, 150]])

# %%
y_pred_test = model.predict(x_test, batch_size=128)
y_pred_test = np.argmax(y_pred_test, axis=1)
score = model.evaluate(x_test, y_test_vec, batch_size=128)
print("The accuracy of the MLFFNN model on the test data:", score[1]*100,"%")

x_min, x_max = x_train[:, 0].min() - 1, x_train[:, 0].max() + 1
y_min, y_max = x_train[:, 1].min() - 1, x_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05),
                     np.arange(y_min, y_max, 0.05))

# here "model" is your model's prediction (classification) function
Z = np.argmax(model.predict(np.c_[xx.ravel(), yy.ravel()]), axis=1)

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.axis('off')

# Plot also the training points
plt.scatter(x_test[:, 0], x_test[:, 1], c=y_test, cmap=plt.cm.jet)
plt.show()

#confusion Matrix
confusion_matrix(y_test, y_pred_test,labels=[0, 1, 2])
# Out:
# 300/300 [==============================] - 0s 22us/step
# The accuracy of the MLFFNN model on the test data: 100.0 %
# array([[100,   0,   0],
#        [  0, 100,   0],
#        [  0,   0, 100]])
